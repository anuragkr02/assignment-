# %%
Q1.What is an Exception in python?Write the difference between Exception and Syntax errors.
ans:=
    An exception is an event, which occurs during the execution of a program that disrupts the normal flow of the program's instructions.
    In general, when a Python script encounters a situation that it cannot cope with, it raises an exception. 
    An exception is a Python object that represents an error.
    
    Both exceptions and errors are the subclasses of a throwable class. 
    The error implies a problem that mostly arises due to the shortage of system resources.
    On the other hand, the exceptions occur during runtime and compile time.

# %%
Q2.What python statements an exception is not handled? Explain with an example.
ans=
   Exceptions which are not subclasses of Exception are not typically handled, because they are used to indicate that the program should terminate.
    They include SystemExit which is raised by sys.exit() and KeyboardInterrupt which is raised when a user wishes to interrupt the program. 
    
example:=
    amount = 10000
if(amount > 2999):
    print("You are eligible to purchase Dsa Self Paced")

# %%
Q3.Which Python statements are used to catch and handle exceptions? Explain with an example.
ans=
In Python, you can catch and handle exceptions using the try and except statements. 
The basic syntax is as follows:

syntax:-
try:

except ExceptionType:
    
Here, ExceptionType is the type of exception that you want to catch and handle. For example, you might use ValueError to catch and handle exceptions related to invalid values.
You can also include multiple except blocks to handle different types of exceptions, and you can use an else block to run code that should only execute if no exception is raised. 
Finally, you can use a finally block to run code that should execute whether an exception is raised or not.
Here's an example of a try-except block that catches an
    
try:
    x = int(input("Enter a number: "))
except ValueError:
    print("Invalid input. Please enter a valid integer.")

# %%
Q4.Explain with an example:
    a.try and else
    b.finally
    c.raise
    
ans:-
    In Python, try and else are used together to handle exceptions that may occur within a block of code.
The basic syntax is:
try:
    # code that may raise an exception
except ExceptionType:
    # code to handle the exception
else:
    # code to execute if no exception was raised

    
Here's an example to illustrate how try and else work together:

try:
    x = int(input("Enter a number: "))
except ValueError:
    print("Invalid input! You must enter a number.")
else:
    print(f"The number you entered is {x}.")

    
    
    
In programming, finally is a block of code that is executed regardless of whether an exception has been thrown or not.
It is typically used to perform some cleanup or resource management tasks, such as closing files, network connections, or database connections, that were opened in a try block.
Here's an example in Python:
  
try:
    f = open("example.txt", "r")
except Error:
    print("An error occurred while reading the file.")
finally:
    f.close()

    

In Python, raise is a keyword used to raise an exception in a program.
When raise is used, it causes an error to occur that can be caught by an exception handler. 


x = -1
if x < 0:
    raise ValueError("x cannot be negative")
Here is an example of using raise in Python:

# %%
Q5.What are Custom Exception in python?Why do we need Exception? Example with an example.
ans:-
    In Python, custom exceptions are user-defined exceptions that allow you to define your own exceptional events, which can be raised and caught like any other built-in exception. 
     To create a custom exception in Python, you need to define a new class that inherits from the built-in Exception class or any of its subclasses.
        
    Exceptions are a mechanism in programming languages to handle errors and unexpected situations that may occur during the execution of a program. They allow the program to gracefully handle errors and recover from them, rather than crashing or producing incorrect results.      
    
    
    
try:
    with open("myfile.txt", "r") as f:
        data = f.read()
except FileNotFoundError:
    print("The file does not exist. Please enter a valid file name.")
except IOError:
    print("An error occurred while reading the file.")

# %%
Q6.Create a ccustom exception class .Use this class to handle an execption.
ans:-
    
class CustomException(Exception):
    def __init__(self, message):
        self.message = message

try:
    x = int(input("Enter a number: "))
    if x < 0:
        raise CustomException("Number must be positive")
except CustomException as e:
    print("Error:", e.message)
